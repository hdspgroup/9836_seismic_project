# %%
import numpy as np
import matplotlib.pyplot as plt
from shapely.geometry import Point, LineString
import geopandas as gpd
import pandas as pd
from fiona.crs import from_epsg
import seaborn as sns

# %%
# !pip3 install contextily
# Out:
# Requirement already satisfied: contextily in /Users/correa/opt/anaconda3/lib/python3.8/site-packages (1.2.0)
# Requirement already satisfied: geopy in /Users/correa/opt/anaconda3/lib/python3.8/site-packages (from contextily) (2.2.0)
# Requirement already satisfied: rasterio in /Users/correa/opt/anaconda3/lib/python3.8/site-packages (from contextily) (1.2.10)
# Requirement already satisfied: requests in /Users/correa/opt/anaconda3/lib/python3.8/site-packages (from contextily) (2.26.0)
# Requirement already satisfied: joblib in /Users/correa/opt/anaconda3/lib/python3.8/site-packages (from contextily) (1.1.0)
# Requirement already satisfied: mercantile in /Users/correa/opt/anaconda3/lib/python3.8/site-packages (from contextily) (1.2.1)
# Requirement already satisfied: matplotlib in /Users/correa/opt/anaconda3/lib/python3.8/site-packages (from contextily) (3.5.0)
# Requirement already satisfied: xyzservices in /Users/correa/opt/anaconda3/lib/python3.8/site-packages (from contextily) (2022.3.0)
# Requirement already satisfied: pillow in /Users/correa/opt/anaconda3/lib/python3.8/site-packages (from contextily) (8.4.0)
# Requirement already satisfied: geographiclib<2,>=1.49 in /Users/correa/opt/anaconda3/lib/python3.8/site-packages (from geopy->contextily) (1.52)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/correa/opt/anaconda3/lib/python3.8/site-packages (from matplotlib->contextily) (4.28.1)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/correa/opt/anaconda3/lib/python3.8/site-packages (from matplotlib->contextily) (3.0.6)
# Requirement already satisfied: setuptools-scm>=4 in /Users/correa/opt/anaconda3/lib/python3.8/site-packages (from matplotlib->contextily) (6.3.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/correa/opt/anaconda3/lib/python3.8/site-packages (from matplotlib->contextily) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /Users/correa/opt/anaconda3/lib/python3.8/site-packages (from matplotlib->contextily) (0.11.0)
# Requirement already satisfied: numpy>=1.17 in /Users/correa/opt/anaconda3/lib/python3.8/site-packages (from matplotlib->contextily) (1.21.4)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/correa/opt/anaconda3/lib/python3.8/site-packages (from matplotlib->contextily) (2.8.2)
# Requirement already satisfied: packaging>=20.0 in /Users/correa/opt/anaconda3/lib/python3.8/site-packages (from matplotlib->contextily) (21.3)
# Requirement already satisfied: six>=1.5 in /Users/correa/opt/anaconda3/lib/python3.8/site-packages (from python-dateutil>=2.7->matplotlib->contextily) (1.16.0)
# Requirement already satisfied: tomli>=1.0.0 in /Users/correa/opt/anaconda3/lib/python3.8/site-packages (from setuptools-scm>=4->matplotlib->contextily) (1.2.2)
# Requirement already satisfied: setuptools in /Users/correa/opt/anaconda3/lib/python3.8/site-packages (from setuptools-scm>=4->matplotlib->contextily) (52.0.0.post20210125)
# Requirement already satisfied: click>=3.0 in /Users/correa/opt/anaconda3/lib/python3.8/site-packages (from mercantile->contextily) (7.1.2)
# Requirement already satisfied: affine in /Users/correa/opt/anaconda3/lib/python3.8/site-packages (from rasterio->contextily) (2.3.1)
# Requirement already satisfied: attrs in /Users/correa/opt/anaconda3/lib/python3.8/site-packages (from rasterio->contextily) (21.2.0)
# Requirement already satisfied: click-plugins in /Users/correa/opt/anaconda3/lib/python3.8/site-packages (from rasterio->contextily) (1.1.1)
# Requirement already satisfied: cligj>=0.5 in /Users/correa/opt/anaconda3/lib/python3.8/site-packages (from rasterio->contextily) (0.7.2)
# Requirement already satisfied: certifi in /Users/correa/opt/anaconda3/lib/python3.8/site-packages (from rasterio->contextily) (2021.10.8)
# Requirement already satisfied: snuggs>=1.4.1 in /Users/correa/opt/anaconda3/lib/python3.8/site-packages (from rasterio->contextily) (1.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /Users/correa/opt/anaconda3/lib/python3.8/site-packages (from requests->contextily) (3.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Users/correa/opt/anaconda3/lib/python3.8/site-packages (from requests->contextily) (2.0.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/correa/opt/anaconda3/lib/python3.8/site-packages (from requests->contextily) (1.26.7)

# %%
#reference system for Magna Sirgas Bogota zone
epsg = 3116

# %% [markdown]
# ### Cargar los datos de la geometría a analizar

# %%
receiver_survey = gpd.GeoDataFrame.from_file('../data_geometry/receiver_POSTPLOT_shapefile/receiver_shapes_tenerife.shp')
source_survey = gpd.GeoDataFrame.from_file('../data_geometry/source_POSTPLOT_shapefile/source_shapes_tenerife.shp')

# %%
receiver_survey
# Out:
#      RECEIVERSE UNKNOWN2       ESTE      NORTE  ELEVACION  UNKNOWN2_1  \
# 0         R3000  10371G1  1025139.0  1252080.9    92.0333      134217
# 1         R3000  10381G1  1025158.3  1252077.6    91.5333      134217
# 2         R3000  10391G1  1025178.6  1252074.0    94.7333      134217
# 3         R3000  10401G1  1025198.0  1252070.6    97.1333      134217
# 4         R3000  10411G1  1025217.6  1252067.3   100.0333      134217
# ...         ...      ...        ...        ...        ...         ...
# 4327      R3252  11781G1  1028791.4  1256555.0   137.2344       90614
# 4328      R3252  11791G1  1028811.2  1256551.5   135.7344       90614
# 4329      R3252  11801G1  1028830.8  1256548.0   135.3344       90614
# 4330      R3252  11811G2  1028830.8  1256548.0   135.3344      104452
# 4331      R3252  11821G3  1028830.8  1256548.0   135.3344      104452
#
#           TYPE                         geometry
# 0     receiver  POINT (1025139.000 1252080.900)
# 1     receiver  POINT (1025158.300 1252077.600)
# 2     receiver  POINT (1025178.600 1252074.000)
# 3     receiver  POINT (1025198.000 1252070.600)
# 4     receiver  POINT (1025217.600 1252067.300)
# ...        ...                              ...
# 4327  receiver  POINT (1028791.400 1256555.000)
# 4328  receiver  POINT (1028811.200 1256551.500)
# 4329  receiver  POINT (1028830.800 1256548.000)
# 4330  receiver  POINT (1028830.800 1256548.000)
# 4331  receiver  POINT (1028830.800 1256548.000)
#
# [4332 rows x 8 columns]

# %%
source_survey
# Out:
#      SHOTSEQ    UNKNOWN  DEPTHFT  UHT  ARCHIVO       ESTE      NORTE  \
# 0      S1054   300010.0     13.0   21       55  1025485.1  1252025.5
# 1      S1095   300010.0     13.0   31       56  1026296.5  1251886.5
# 2      S1216  3000100.0      8.5    9       57  1028671.4  1251467.3
# 3      S1198  3000100.0      7.5    6       58  1028326.9  1251533.7
# 4      S1162  3000100.0      8.5   14       59  1027614.4  1251650.9
# ...      ...        ...      ...  ...      ...        ...        ...
# 3390   S1156   324510.0     13.0   83      600  1028342.9  1256500.8
# 3391   S1094   325110.0     13.0  223      601  1027140.7  1256832.3
# 3392   S1179   325010.0     13.0  133      602  1028810.2  1256524.9
# 3393   S1094   325010.0     13.0  213      603  1027140.7  1256819.0
# 3394   S1180   325110.0     13.0  123      604  1028843.4  1256533.9
#
#            ELEVACION    TYPE                         geometry
# 0      80.3333160428  source  POINT (1025485.100 1252025.500)
# 1     105.9333161554  source  POINT (1026296.500 1251886.500)
# 2      82.5333162006  source  POINT (1028671.400 1251467.300)
# 3      82.6333162053  source  POINT (1028326.900 1251533.700)
# 4      81.8333162219  source  POINT (1027614.400 1251650.900)
# ...              ...     ...                              ...
# 3390   96.6348114928  source  POINT (1028342.900 1256500.800)
# 3391  127.2348115211  source  POINT (1027140.700 1256832.300)
# 3392  136.7348115257  source  POINT (1028810.200 1256524.900)
# 3393  127.5348115334  source  POINT (1027140.700 1256819.000)
# 3394  135.0348115432  source  POINT (1028843.400 1256533.900)
#
# [3395 rows x 10 columns]

# %% [markdown]
# #### Unificar los datos de receptores y fuentes en el mismo data frame para realizar cálculos como mapa de cobertura (fold) y visualización de la geometría

# %%
survey = receiver_survey.append(source_survey)

# %%
survey
# Out:
#      RECEIVERSE UNKNOWN2       ESTE      NORTE       ELEVACION  UNKNOWN2_1  \
# 0         R3000  10371G1  1025139.0  1252080.9         92.0333    134217.0
# 1         R3000  10381G1  1025158.3  1252077.6         91.5333    134217.0
# 2         R3000  10391G1  1025178.6  1252074.0         94.7333    134217.0
# 3         R3000  10401G1  1025198.0  1252070.6         97.1333    134217.0
# 4         R3000  10411G1  1025217.6  1252067.3        100.0333    134217.0
# ...         ...      ...        ...        ...             ...         ...
# 3390        NaN      NaN  1028342.9  1256500.8   96.6348114928         NaN
# 3391        NaN      NaN  1027140.7  1256832.3  127.2348115211         NaN
# 3392        NaN      NaN  1028810.2  1256524.9  136.7348115257         NaN
# 3393        NaN      NaN  1027140.7  1256819.0  127.5348115334         NaN
# 3394        NaN      NaN  1028843.4  1256533.9  135.0348115432         NaN
#
#           TYPE                         geometry SHOTSEQ   UNKNOWN  DEPTHFT  \
# 0     receiver  POINT (1025139.000 1252080.900)     NaN       NaN      NaN
# 1     receiver  POINT (1025158.300 1252077.600)     NaN       NaN      NaN
# 2     receiver  POINT (1025178.600 1252074.000)     NaN       NaN      NaN
# 3     receiver  POINT (1025198.000 1252070.600)     NaN       NaN      NaN
# 4     receiver  POINT (1025217.600 1252067.300)     NaN       NaN      NaN
# ...        ...                              ...     ...       ...      ...
# 3390    source  POINT (1028342.900 1256500.800)   S1156  324510.0     13.0
# 3391    source  POINT (1027140.700 1256832.300)   S1094  325110.0     13.0
# 3392    source  POINT (1028810.200 1256524.900)   S1179  325010.0     13.0
# 3393    source  POINT (1027140.700 1256819.000)   S1094  325010.0     13.0
# 3394    source  POINT (1028843.400 1256533.900)   S1180  325110.0     13.0
#
#         UHT  ARCHIVO
# 0       NaN      NaN
# 1       NaN      NaN
# 2       NaN      NaN
# 3       NaN      NaN
# 4       NaN      NaN
# ...     ...      ...
# 3390   83.0    600.0
# 3391  223.0    601.0
# 3392  133.0    602.0
# 3393  213.0    603.0
# 3394  123.0    604.0
#
# [7727 rows x 13 columns]

# %%
#IDENTIFICAR SHOTS ESPECIFICOS
surv = source_survey[source_survey['SHOTSEQ']=='S1126']
#surv = surv[surv['UNKNOWN']<300000]
#print('Min='+str(surv['UNKNOWN'].min())+', Max='+str(surv['UNKNOWN'].max()))
surv['shotid'] = surv['UNKNOWN'].astype(str).str[0:4] #Los primeros 4 numeros de la columna UNKNOWN son el identificador del shot
surv['shotid'] = surv['shotid'].astype(int)
surv
#survey = receiver_survey.append(surv[surv['shotid']<3089]) #escoger solo los que me interesan
# Out:
# /Users/correa/opt/anaconda3/lib/python3.8/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
#      SHOTSEQ    UNKNOWN  DEPTHFT  UHT  ARCHIVO       ESTE      NORTE  \
# 26     S1126   300110.0     13.0   14       91  1026907.5  1251803.3
# 34     S1126   300210.0     13.0   22       99  1026909.9  1251820.2
# 71     S1126   300610.0     13.0   16      136  1026923.1  1251899.2
# 80     S1126   300710.0     13.0   11      145  1026931.2  1251913.5
# 88     S1126   300810.0     13.0   10      153  1026928.1  1251934.4
# ...      ...        ...      ...  ...      ...        ...        ...
# 2611   S1126   318810.0     13.0   92      802  1027553.4  1255479.5
# 3099   S1126  3223100.0      8.0   63      301  1027678.9  1256176.1
# 3116   S1126  3224100.0      8.5   83      318  1027680.4  1256189.2
# 3125   S1126  3225100.0      8.5   53      327  1027683.7  1256207.1
# 3132   S1126  3226100.0      8.5   53      334  1027692.6  1256227.1
#
#            ELEVACION    TYPE                         geometry  shotid
# 26    103.4334103244  source  POINT (1026907.500 1251803.300)    3001
# 34     99.9334104233  source  POINT (1026909.900 1251820.200)    3002
# 71     91.0334114605  source  POINT (1026923.100 1251899.200)    3006
# 80     86.3334115228  source  POINT (1026931.200 1251913.500)    3007
# 88     85.7334124203  source  POINT (1026928.100 1251934.400)    3008
# ...              ...     ...                              ...     ...
# 2611   84.6346110604  source  POINT (1027553.400 1255479.500)    3188
# 3099   81.9347122721  source  POINT (1027678.900 1256176.100)    3223
# 3116   81.7347131317  source  POINT (1027680.400 1256189.200)    3224
# 3125   82.0347132349  source  POINT (1027683.700 1256207.100)    3225
# 3132     82.73471352  source  POINT (1027692.600 1256227.100)    3226
#
# [146 rows x 11 columns]

# %%
survey.plot(figsize=(12,12), column='TYPE', cmap="bwr", markersize=20)
plt.grid()
plt.show()

# %%
survey.crs
# Out:
# <Derived Projected CRS: EPSG:3116>
# Name: MAGNA-SIRGAS / Colombia Bogota zone
# Axis Info [cartesian]:
# - N[north]: Northing (metre)
# - E[east]: Easting (metre)
# Area of Use:
# - name: Colombia - onshore between 1°30'W and 1°30'E of Bogota (75°35'W and 72°35'W of Greenwich).
# - bounds: (-75.59, -2.51, -72.58, 11.82)
# Coordinate Operation:
# - name: Colombia MAGNA Bogota zone
# - method: Transverse Mercator
# Datum: Marco Geocentrico Nacional de Referencia
# - Ellipsoid: GRS 1980
# - Prime Meridian: Greenwich

# %%
import contextily as cx
ax = survey.plot(figsize=(12,12), column='TYPE', cmap="bwr", markersize=20)
cx.add_basemap(ax, crs=survey.crs, source=cx.providers.OpenStreetMap.Mapnik)

# %% [markdown]
# ### Calcular parámetros de la geometría

# %%
NS = source_survey.shape[0]
NR = receiver_survey.shape[0]
print('Number of Sources =', NS)
print('Number of Receivers = ', NR)
# Out:
# Number of Sources = 3395
# Number of Receivers =  4332

# %%
#Calculate number of receiver lines and number of receivers on each line
temprec = np.asarray(receiver_survey.RECEIVERSE)
rec_lines, rec_per_line = np.unique(temprec, return_counts=True)
NRL = rec_lines.size # Number of receiver lines
print('Receiver lines: ', rec_lines)
print('Receivers on each line: ', rec_per_line) #number of receivers per line
print('Number of receiver lines: ', NRL)
# Out:
# Receiver lines:  ['R3000' 'R3014' 'R3028' 'R3042' 'R3056' 'R3070' 'R3084' 'R3098' 'R3112'
#  'R3126' 'R3140' 'R3154' 'R3168' 'R3182' 'R3196' 'R3210' 'R3224' 'R3238'
#  'R3252']
# Receivers on each line:  [198 198 198 198 234 252 252 252 252 243 234 235 234 234 234 234 234 234
#  182]
# Number of receiver lines:  19

# %% [markdown]
# Info organizada de la geometría (Receptoras)

# %%
Rec_info = pd.DataFrame(rec_lines, columns =['RECEIVERSE'])
Rec_info['type'] = 'receiver'
Rec_info['amount'] = rec_per_line
Rec_info.head()
# Out:
#   RECEIVERSE      type  amount
# 0      R3000  receiver     198
# 1      R3014  receiver     198
# 2      R3028  receiver     198
# 3      R3042  receiver     198
# 4      R3056  receiver     234

# %%
#Calculate number of source lines and number of sources on each line
tempsrc = np.asarray(source_survey.SHOTSEQ)
src_lines, src_per_line = np.unique(tempsrc, return_counts=True)
NSL = src_lines.size # Number of source lines
print('Source lines: ', src_lines)
print('Sources on each line: ', src_per_line)#number of sources per line
print('Number of source lines: ', NSL)

#Otras formas de calcular el numero de fuentes en cada linea
#shot_count = source_survey.groupby('SHOTSEQ')['UNKNOWN'].count()
#shot_count = source_survey['SHOTSEQ'].value_counts()
#print(shot_count)
# Out:
# Source lines:  ['S1000' 'S1001' 'S1002' 'S1003' 'S1004' 'S1005' 'S1006' 'S1014' 'S1015'
#  'S1016' 'S1017' 'S1018' 'S1019' 'S1020' 'S1021' 'S1023' 'S1027' 'S1029'
#  'S1030' 'S1031' 'S1032' 'S1034' 'S1036' 'S1037' 'S1038' 'S1040' 'S1041'
#  'S1042' 'S1043' 'S1044' 'S1045' 'S1046' 'S1047' 'S1048' 'S1049' 'S1050'
#  'S1051' 'S1052' 'S1053' 'S1054' 'S1055' 'S1056' 'S1058' 'S1059' 'S1061'
#  'S1062' 'S1063' 'S1064' 'S1065' 'S1066' 'S1067' 'S1068' 'S1069' 'S1070'
#  'S1071' 'S1072' 'S1073' 'S1074' 'S1075' 'S1076' 'S1077' 'S1078' 'S1079'
#  'S1080' 'S1081' 'S1084' 'S1085' 'S1086' 'S1087' 'S1088' 'S1089' 'S1090'
#  'S1091' 'S1092' 'S1093' 'S1094' 'S1095' 'S1096' 'S1097' 'S1098' 'S1099'
#  'S1100' 'S1101' 'S1102' 'S1103' 'S1104' 'S1105' 'S1106' 'S1107' 'S1108'
#  'S1109' 'S1110' 'S1111' 'S1112' 'S1113' 'S1114' 'S1115' 'S1117' 'S1118'
#  'S1119' 'S1120' 'S1121' 'S1122' 'S1123' 'S1124' 'S1125' 'S1126' 'S1127'
#  'S1128' 'S1129' 'S1130' 'S1131' 'S1132' 'S1133' 'S1134' 'S1135' 'S1136'
#  'S1137' 'S1138' 'S1139' 'S1140' 'S1141' 'S1142' 'S1143' 'S1144' 'S1145'
#  'S1146' 'S1147' 'S1148' 'S1149' 'S1150' 'S1151' 'S1152' 'S1153' 'S1154'
#  'S1155' 'S1156' 'S1157' 'S1158' 'S1159' 'S1160' 'S1161' 'S1162' 'S1163'
#  'S1164' 'S1165' 'S1166' 'S1167' 'S1168' 'S1169' 'S1171' 'S1173' 'S1174'
#  'S1175' 'S1176' 'S1177' 'S1178' 'S1179' 'S1180' 'S1181' 'S1182' 'S1183'
#  'S1184' 'S1185' 'S1186' 'S1187' 'S1188' 'S1189' 'S1190' 'S1191' 'S1192'
#  'S1193' 'S1194' 'S1195' 'S1196' 'S1197' 'S1198' 'S1199' 'S1200' 'S1201'
#  'S1202' 'S1203' 'S1204' 'S1205' 'S1206' 'S1209' 'S1210' 'S1211' 'S1212'
#  'S1213' 'S1214' 'S1215' 'S1216' 'S1217' 'S1218' 'S1219' 'S1220' 'S1221'
#  'S1230' 'S1231' 'S1232' 'S1233' 'S1234' 'S1235' 'S1236' 'S1237' 'S1240'
#  'S1241' 'S1243' 'S1251' 'S1252' 'S1253' 'S1254' 'S1258' 'S1259' 'S1260'
#  'S1264' 'S1265' 'S1266' 'S1267' 'S1268' 'S1269' 'S1270' 'S1271' 'S1272'
#  'S1273' 'S1274' 'S1275' 'S1276' 'S1279' 'S1280' 'S1282' 'S1284' 'S1285'
#  'S1286' 'S1287' 'S1288']
# Sources on each line:  [ 82   2   6   5   3   1   3   4   5   2   1  78   2   2   1   3   1   2
#    1   9   2   2 190   8  15   3   4   5   4   3  10   7   7   6   9   6
#    5   3   7 173   1   1  12   2   4   5   1   9   3   5   6  12   9  12
#    3 138   8   5  10   5   6   5   5   5   6   1   1   3   4   7   9 150
#   11  12   2  15  11   2   2   3   3   5   2  11   2   3   5   8  16 151
#   13  14   8   7   1   5   2  13   2   3   3   5   6   7  14  18 146  13
#    8   3   2   1   2   2   7  23  11   9   5  10  14   7   4  19  86  15
#    8  12   7   3   6   9   5  15  10   2   3   4   4   6  14  17 145  10
#    5   4  14   3   1   1   1   2   1   1   1   2   6  13 157   8  18  21
#    7   3   4   2   1   6   2   4   1   3   2   6   6  20 143  18   9   7
#    4   4   3   3   2   1   1   2   2   1   8  10 195   9   3   3   2   1
#    2   5  10  22 188   4   1   3   2   1   3   3  65   3   3   3   6   1
#    1   8   3   6  15   5   9   4   3   5   3   7   1   1   1   1   3   4
#    5   4  37]
# Number of source lines:  237

# %%
Sou_info = pd.DataFrame(src_lines, columns =['SHOTSEQ'])
Sou_info['type'] = 'source'
Sou_info['amount'] = src_per_line
Sou_info.head(20)
# Out:
#    SHOTSEQ    type  amount
# 0    S1000  source      82
# 1    S1001  source       2
# 2    S1002  source       6
# 3    S1003  source       5
# 4    S1004  source       3
# 5    S1005  source       1
# 6    S1006  source       3
# 7    S1014  source       4
# 8    S1015  source       5
# 9    S1016  source       2
# 10   S1017  source       1
# 11   S1018  source      78
# 12   S1019  source       2
# 13   S1020  source       2
# 14   S1021  source       1
# 15   S1023  source       3
# 16   S1027  source       1
# 17   S1029  source       2
# 18   S1030  source       1
# 19   S1031  source       9

# %%
shot_count = source_survey['SHOTSEQ'].value_counts()
shot_count.head(50)
# Out:
# S1216    195
# S1036    190
# S1234    188
# S1054    173
# S1180    157
# S1108    151
# S1090    150
# S1126    146
# S1162    145
# S1198    143
# S1072    138
# S1144     86
# S1000     82
# S1018     78
# S1252     65
# S1288     37
# S1135     23
# S1233     22
# S1183     21
# S1197     20
# S1143     19
# S1182     18
# S1199     18
# S1125     18
# S1161     17
# S1107     16
# S1268     15
# S1145     15
# S1153     15
# S1094     15
# S1038     15
# S1110     14
# S1140     14
# S1160     14
# S1124     14
# S1166     14
# S1109     13
# S1127     13
# S1179     13
# S1117     13
# S1092     12
# S1070     12
# S1058     12
# S1068     12
# S1147     12
# S1136     11
# S1095     11
# S1102     11
# S1091     11
# S1075     10
# Name: SHOTSEQ, dtype: int64

# %% [markdown]
# ### Calcular distancia entre fuentes para cada línea

# %%
def calculate_srcdist(temps,coord):
    temps = temps.sort_values(by=[coord])    #Ordenar los puntos de una línea de norte a sur
    temps['idx'] = range(temps.shape[0])       #Asignar indice segun el orden de los puntos en la línea 
    temps = temps[['SHOTSEQ','geometry','idx']]  #Extraer solo la geometria y el indice de cada registro
    copy1_temps = temps['geometry'][:-1] #From first to penultimate
    copy2_temps = temps['geometry'][1:] #From second to last
    temps['distances'] = copy2_temps.distance(copy1_temps, align=False)  #Calcular distancia de un shot con el anterior
    temps.iloc[0,3] = 0    #Fijar la distancia del primer shot en cada línea en cero (porque calculo la distancia de un shot con el anterior)
    return temps
    

sourcedist_df = pd.DataFrame(columns = ['SHOTSEQ', 'geometry', 'idx', 'distances']) #Crear dataframe global vacío

for line in src_lines:
    temp_df = source_survey[source_survey['SHOTSEQ']==line]
    temp_df = calculate_srcdist(temp_df,'NORTE')
    sourcedist_df = sourcedist_df.append(temp_df)    #Agregar los registros de la línea de shot analizada al dataframe global

# %%
sourcedist_df.head()
# Out:
#      SHOTSEQ                         geometry idx  distances
# 2215   S1000  POINT (1024962.000 1255255.100)   0   0.000000
# 2242   S1000  POINT (1024959.700 1255265.600)   1  10.748953
# 2265   S1000  POINT (1024966.800 1255293.300)   2  28.595454
# 2275   S1000  POINT (1024969.900 1255307.300)   3  14.339107
# 2287   S1000  POINT (1024971.600 1255332.200)   4  24.957965

# %% [markdown]
# #### Truncar las líneas de fuentes que tengan menos de cierta cantidad de fuentes, para poder calcular coherencia mutua

# %%
#source_survey['SHOTSEQ'].value_counts()>100
inds = np.where(src_per_line >21) # 22 es el umbral para obtener 17 lineas fuentes como dice el reporte observador
trunc_src_lines = src_lines[inds]
sourcedist_df = sourcedist_df.loc[sourcedist_df['SHOTSEQ'].isin(trunc_src_lines)]
sourcedist_df.head()
# Out:
#      SHOTSEQ                         geometry idx  distances
# 2215   S1000  POINT (1024962.000 1255255.100)   0   0.000000
# 2242   S1000  POINT (1024959.700 1255265.600)   1  10.748953
# 2265   S1000  POINT (1024966.800 1255293.300)   2  28.595454
# 2275   S1000  POINT (1024969.900 1255307.300)   3  14.339107
# 2287   S1000  POINT (1024971.600 1255332.200)   4  24.957965

# %% [markdown]
# #### Calcular distancia promedio entre fuentes de cada línea
# Observación: Estos promedios tienen outliers debido a las fuentes ubicadas en off-set que generan líneas de disparos intermedias, con un número muy reducido de fuentes (hasta una sola fuente). Por eso en el paso anterior se descartaron las líneas con una cantidad reducida de fuentes.

# %%
avg_shot_dist = sourcedist_df.groupby('SHOTSEQ')['distances'].mean()

plt.figure(figsize=(19, 6))
#plt.bar(src_lines,avg_shot_dist) #Antes de seleccionar subconjunto de líneas
plt.bar(trunc_src_lines,avg_shot_dist)
plt.xticks(rotation='vertical')
plt.xlabel('Lineas de shots')
plt.ylabel('Dist. promedio entre shots [m]')
plt.show()

#avg_shot_dist.head(18)

# %%
#Distancia promedio entre fuentes para todas las líneas
print('Dist. promedio entre shots/linea = ',avg_shot_dist.mean())
print('Std. dev dist. entre shots/linea = ',avg_shot_dist.std())
#Numero de total de shots
print('Numero total de shots = ',sourcedist_df.shape[0])
# Out:
# Dist. promedio entre shots/linea =  178.3004159082483
# Std. dev dist. entre shots/linea =  123.8670695545404
# Numero total de shots =  2617

# %% [markdown]
# #### Calcular distancia entre receptores para cada línea

# %%
def calculate_recdist(temps,coord):
    temps = temps.sort_values(by=[coord])    #Ordenar los puntos de una línea de norte a sur
    temps['idx'] = range(temps.shape[0])       #Asignar indice segun el orden de los puntos en la línea 
    temps = temps[['RECEIVERSE','geometry','idx']]  #Extraer solo la geometria y el indice de cada registro
    copy1_temps = temps['geometry'][:-1] #From first to penultimate
    copy2_temps = temps['geometry'][1:] #From second to last
    temps['distances'] = copy2_temps.distance(copy1_temps, align=False)  #Calcular distancia de un shot con el anterior
    temps.iloc[0,3] = 0    #Fijar la distancia del primer shot en cada línea en cero
    return temps

receivdist_df = pd.DataFrame(columns = ['RECEIVERSE', 'geometry', 'idx', 'distances']) #Crear dataframe global vacío

for line in rec_lines:
    temp_df = receiver_survey[receiver_survey['RECEIVERSE']==line]
    temp_df = calculate_recdist(temp_df,'ESTE')        
    receivdist_df = receivdist_df.append(temp_df)    #Agregar los registros de la línea de receptores analizada al dataframe global

# %%
receivdist_df.head()
# Out:
#   RECEIVERSE                         geometry idx  distances
# 0      R3000  POINT (1025139.000 1252080.900)   0   0.000000
# 1      R3000  POINT (1025158.300 1252077.600)   1  19.580092
# 2      R3000  POINT (1025178.600 1252074.000)   2  20.616741
# 3      R3000  POINT (1025198.000 1252070.600)   3  19.695685
# 4      R3000  POINT (1025217.600 1252067.300)   4  19.875865

# %% [markdown]
# #### Calcular distancias promedio para cada línea de receptoras
# Observación: La distancia promedio en cada línea no se ve afectada debido a que no hay casos de receptoras ubicadas en offset.

# %%
avg_receiv_dist = receivdist_df.groupby('RECEIVERSE')['distances'].mean()

plt.figure(figsize=(16, 4))
plt.bar(rec_lines,avg_receiv_dist)
plt.xticks(rotation='vertical')
plt.xlabel('Lineas de receptoras')
plt.ylabel('Dist. promedio entre receptoras [m]')
#plt.grid(axis = 'y')
plt.show()

#avg_receiv_dist.head(18)

# %% [markdown]
# #### Calcular distancia entre líneas de shots

# %%
temp_este = source_survey.groupby(['SHOTSEQ'])['ESTE'].mean().reset_index()

temp_este.head()
# Out:
#   SHOTSEQ          ESTE
# 0   S1000  1.025146e+06
# 1   S1001  1.025084e+06
# 2   S1002  1.025117e+06
# 3   S1003  1.025070e+06
# 4   S1004  1.025079e+06

# %%
copy1_temp_este = temp_este['ESTE'][:-1] #From first to penultimate
copy2_temp_este = temp_este['ESTE'][1:] #From second to last
aaaaaa = copy2_temp_este.distance(copy1_temp_este, align=False)  #Calcular distancia de un shot con el anterior
#aaaaaa=aaaaaa[1:]
print(aaaaaa)
#for line in temp_este['SHOTSEQ']:
#    temp_ddf = source_survey[source_survey['SHOTSEQ']==line]
#    temp_ddf = calculate_srcdist(temp_ddf,'ESTE')
#    sourcelinedist_df = sourcelinedist_df.append(temp_ddf)    #Agregar los registros de la línea de shot analizada al dataframe global
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-29-178dd7d0c3ca> in <module>
#       1 copy1_temp_este = temp_este['ESTE'][:-1] #From first to penultimate
#       2 copy2_temp_este = temp_este['ESTE'][1:] #From second to last
# ----> 3 aaaaaa = copy2_temp_este.distance(copy1_temp_este, align=False)  #Calcular distancia de un shot con el anterior
#       4 #aaaaaa=aaaaaa[1:]
#       5 print(aaaaaa)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'distance'

# %%
print(temp_este['ESTE'].size)
# Out:
# 237

# %%
copy1_temp_este = temp_este['ESTE'][:-1] #From first to penultimate
copy2_temp_este = temp_este['ESTE'][1:] #From second to last
temp_dist= copy2_temp_este.distance(copy1_temp_este, align=False)  #Calcular distancia de una linea con la anterior
print(temp_dist)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'ESTE'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-110-84beda521acf> in <module>
# ----> 1 copy1_temp_este = temp_este['ESTE'][:-1] #From first to penultimate
#       2 copy2_temp_este = temp_este['ESTE'][1:] #From second to last
#       3 temp_dist= copy2_temp_este.distance(copy1_temp_este, align=False)  #Calcular distancia de una linea con la anterior
#       4 print(temp_dist)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/series.py in __getitem__(self, key)
#     940
#     941         elif key_is_scalar:
# --> 942             return self._get_value(key)
#     943
#     944         if is_hashable(key):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/series.py in _get_value(self, label, takeable)
#    1049
#    1050         # Similar to Index.get_value, but we do not fall back to positional
# -> 1051         loc = self.index.get_loc(label)
#    1052         return self.index._get_values_for_loc(self, loc, label)
#    1053
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: 'ESTE'

# %% [markdown]
# ### Calcular todos los parámetros de fuentes de la geometria submuestreada

# %%
def calculate_geometry_params(gdf,tau):
    #Truncar linear de shots
    inds = np.where(src_per_line >tau) 
    trunc_src_lines = src_lines[inds]
    gdf = gdf.loc[gdf['SHOTSEQ'].isin(trunc_src_lines)]

    #Calcular distancia promedio de shots por linea y graficar
    avg_shot_dist = gdf.groupby('SHOTSEQ')['distances'].mean()
    # %matplotlib inline 
    plt.figure(figsize=(19, 6))
    plt.bar(trunc_src_lines,avg_shot_dist)
    plt.xticks(rotation='vertical')
    plt.xlabel('Lineas de shots')
    plt.ylabel('Dist. promedio entre shots [m]')
    plt.show()
    
    return(avg_shot_dist, gdf, trunc_src_lines)
    
(avg_shots,trunc_gdf, trunc_src_lines) = calculate_geometry_params(sourcedist_df, 22)
    
#Imprimir resultados
print('Dist. promedio entre shots/linea = ',avg_shots.mean()) #Distancia promedio entre fuentes para todas las líneas
print('Std. dev dist. entre shots/linea = ',avg_shots.std()) #Desviacion estandar distancia 
print('Numero total de shots = ',trunc_gdf.shape[0])  #Numero de total de shots
# Out:
# Dist. promedio entre shots/linea =  38.95363313389664
# Std. dev dist. entre shots/linea =  34.81020753248666
# Numero total de shots =  2147

# %% [markdown]
# #### Graficar geometría con subconjunto de líneas fuente seleccionadas

# %%
#import contextily as cx

#inds = np.where(src_per_line >22) # Ya fue calculado - 22 es el umbral para obtener 17 lineas fuentes como dice el reporte observador
source_trunc = source_survey.loc[source_survey['SHOTSEQ'].isin(trunc_src_lines)] #trunc_src_lines ya fue calculado
survey = receiver_survey.append(source_trunc)
ax = survey.plot(figsize=(12,12), column='TYPE', cmap="bwr", markersize=20)
cx.add_basemap(ax, crs=survey.crs, source=cx.providers.OpenStreetMap.Mapnik)
plt.grid()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-45-3f2936644f32> in <module>
#       5 survey = receiver_survey.append(source_trunc)
#       6 ax = survey.plot(figsize=(12,12), column='TYPE', cmap="bwr", markersize=20)
# ----> 7 cx.add_basemap(ax, crs=survey.crs, source=cx.providers.OpenStreetMap.Mapnik)
#       8 plt.grid()
#       9 plt.show()
#
# NameError: name 'cx' is not defined

# %% [markdown]
# ### Calcular Fold

# %%
#Make a Station ID column, so we can recognize the stations again.
sid = np.arange(len(survey))
survey['SID'] = sid

# %%
s2 = survey.rotate(10, origin=survey.unary_union.centroid)
s2
# Out:
# 0       POINT (1025541.039 1251701.950)
# 1       POINT (1025560.618 1251702.052)
# 2       POINT (1025581.235 1251702.031)
# 3       POINT (1025600.931 1251702.052)
# 4       POINT (1025620.806 1251702.205)
#                      ...
# 3379    POINT (1028056.025 1256649.436)
# 3380    POINT (1028409.485 1256633.370)
# 3384    POINT (1028055.045 1256640.023)
# 3385    POINT (1028413.751 1256650.064)
# 3394    POINT (1028415.905 1256730.561)
# Length: 6479, dtype: geometry

# %%
s2.plot(figsize=(12,12), cmap="bwr", markersize=20)
plt.grid()
plt.show()

# %%
#Calculate midpoints
rcvrs = s2[0:NR-1]
srcs = s2[NR:]

midpoint_list = [LineString([r, s]).interpolate(0.5, normalized=True)
                 for r in rcvrs
                 for s in srcs]

# %%
# Make a list of all the offsets when we count the midpoints into the bins.
offsets = [r.distance(s)
           for r in rcvrs
           for s in srcs]

azimuths = [np.arctan((r.x - s.x)/(r.y - s.y))
            for r in rcvrs
            for s in srcs]

# %%
# Make a Geoseries of the midpoints, offsets and azimuths:
midpoints = gpd.GeoDataFrame({'geometry': midpoint_list,
                              'offset': offsets,
                              'azimuth': np.degrees(azimuths),
                              })

midpoints[:5]
# Out:
#                           geometry       offset    azimuth
# 0  POINT (1025716.270 1251704.721)   350.505877  89.094151
# 1  POINT (1027333.681 1251706.508)  3585.297020  89.854307
# 2  POINT (1027158.283 1251709.293)  3234.522260  89.739850
# 3  POINT (1026797.270 1251705.141)  2512.469932  89.854476
# 4  POINT (1025536.912 1251704.624)     9.835141 -57.060111

# %%
ax = midpoints.plot(figsize=(12,12),column='offset', cmap="bwr", markersize=15)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-52-bd4a032ecb21> in <module>
# ----> 1 ax = midpoints.plot(figsize=(12,12),column='offset', cmap="bwr", markersize=15)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/geopandas/plotting.py in __call__(self, *args, **kwargs)
#     948         kind = kwargs.pop("kind", "geo")
#     949         if kind == "geo":
# --> 950             return plot_dataframe(data, *args, **kwargs)
#     951         if kind in self._pandas_kinds:
#     952             # Access pandas plots
#
# ~/opt/anaconda3/lib/python3.8/site-packages/geopandas/plotting.py in plot_dataframe(df, column, cmap, color, ax, cax, categorical, legend, scheme, k, vmin, vmax, markersize, figsize, legend_kwds, categories, classification_kwds, missing_kwds, aspect, **style_kwds)
#     813
#     814     # decompose GeometryCollections
# --> 815     geoms, multiindex = _flatten_multi_geoms(df.geometry, prefix="Geom")
#     816     values = np.take(values, multiindex, axis=0)
#     817     nan_idx = np.take(nan_idx, multiindex, axis=0)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/geopandas/plotting.py in _flatten_multi_geoms(geoms, prefix)
#      45     components, component_index = [], []
#      46
# ---> 47     if not geoms.geom_type.str.startswith(prefix).any():
#      48         return geoms, np.arange(len(geoms))
#      49
#
# ~/opt/anaconda3/lib/python3.8/site-packages/geopandas/base.py in geom_type(self)
#     191         dtype: object
#     192         """
# --> 193         return _delegate_property("geom_type", self)
#     194
#     195     @property
#
# ~/opt/anaconda3/lib/python3.8/site-packages/geopandas/base.py in _delegate_property(op, this)
#      64     # type: (str, GeoSeries) -> GeoSeries/Series
#      65     a_this = GeometryArray(this.geometry.values)
# ---> 66     data = getattr(a_this, op)
#      67     if isinstance(data, GeometryArray):
#      68         from .geoseries import GeoSeries
#
# ~/opt/anaconda3/lib/python3.8/site-packages/geopandas/array.py in geom_type(self)
#     462     @property
#     463     def geom_type(self):
# --> 464         return vectorized.geom_type(self.data)
#     465
#     466     @property
#
# ~/opt/anaconda3/lib/python3.8/site-packages/geopandas/_vectorized.py in geom_type(data)
#     528         return geometry_type_values[np.searchsorted(geometry_type_ids, res)]
#     529     else:
# --> 530         return _unary_op("geom_type", data, null_value=None)
#     531
#     532
#
# ~/opt/anaconda3/lib/python3.8/site-packages/geopandas/_vectorized.py in _unary_op(op, left, null_value)
#     459     # type: (str, np.array[geoms], Any) -> np.array
#     460     """Unary operation that returns a Series"""
# --> 461     data = [getattr(geom, op, null_value) for geom in left]
#     462     return np.array(data, dtype=np.dtype(type(null_value)))
#     463
#
# ~/opt/anaconda3/lib/python3.8/site-packages/geopandas/_vectorized.py in <listcomp>(.0)
#     459     # type: (str, np.array[geoms], Any) -> np.array
#     460     """Unary operation that returns a Series"""
# --> 461     data = [getattr(geom, op, null_value) for geom in left]
#     462     return np.array(data, dtype=np.dtype(type(null_value)))
#     463
#
# ~/opt/anaconda3/lib/python3.8/site-packages/shapely/geometry/base.py in geom_type(self)
#     426     def geom_type(self):
#     427         """Name of the geometry's type, such as 'Point'"""
# --> 428         return self.geometryType()
#     429
#     430     # Real-valued properties and methods
#
# ~/opt/anaconda3/lib/python3.8/site-packages/shapely/geometry/base.py in geometryType(self)
#     360
#     361     def geometryType(self):
# --> 362         return geometry_type_name(self._geom)
#     363
#     364     @property
#
# ~/opt/anaconda3/lib/python3.8/site-packages/shapely/geometry/base.py in geometry_type_name(g)
#      65     if g is None:
#      66         raise ValueError("Null geometry has no type")
# ---> 67     return GEOMETRY_TYPES[lgeos.GEOSGeomTypeId(g)]
#      68
#      69
#
# KeyboardInterrupt:

# %%
#Spider plot (Might not be needed, but just in case)
midpoints['offsetx'] = offsets * np.cos(azimuths)
midpoints['offsety'] = offsets * np.sin(azimuths)
midpoints[:5].offsetx  # Easy!
# Out:
# 0     5.541285
# 1     9.116786
# 2    14.686223
# 3     6.381365
# 4     5.347945
# Name: offsetx, dtype: float64

# %%
x = [m.geometry.x for i, m in midpoints.iterrows()]
y = [m.geometry.y for i, m in midpoints.iterrows()]

# %%
#%matplotlib qt
fig = plt.figure(figsize=(12,8))
plt.quiver(x, y, midpoints.offsetx, midpoints.offsety, units='xy', width=0.5, scale=1/0.025, pivot='mid', headlength=0)
plt.axis('equal')
plt.show()

# %% [markdown]
# ### Use ideal Preplot to create the Bins

# %%
#BINS - Created as new geometry from the ideal geometry (pre-plot)
# Parameters from report
si = 20            # Source point interval (m)
ri = 20            # Receiver point interval (m)
extent_c = s2.total_bounds 
extent = [extent_c[2]-extent_c[0], extent_c[3]-extent_c[1]]
#Extract coordinates of the bottom-left point
xmi = extent_c[0] #Easting of bottom-left corner of grid (m)
ymi = extent_c[1] #Northing of bottom-left corner (m)
rperline = int(extent[0]/ri) + 2
sperline = int(extent[1]/si) + 2

# %%
extent
# Out:
# [5769.373822248774, 5042.510292393621]

# %%
# Load preplot geometry
pre_r_survey = gpd.GeoDataFrame.from_file('../data_geometry/receiver_PREPLOT_shapefile/receiver_PREPLOT_shapefile.shp')
pre_s_survey = gpd.GeoDataFrame.from_file('../data_geometry/source_PREPLOT_shapefile/source_PREPLOT_shapefile.shp')
pre_r_survey['TYPE']='receiver'
pre_s_survey['TYPE']='source'

# %%
pre_survey = pre_r_survey.append(pre_s_survey)
#pre_survey.plot(figsize=(12,12), column='TYPE', cmap="bwr", markersize=20)
#plt.grid()
#plt.show()
pre_survey_rot = pre_survey.rotate(10, origin=pre_survey.unary_union.centroid)
pre_survey_rot.plot(figsize=(12,12), cmap="bwr", markersize=20)
plt.grid()
plt.show()

# %%
#Create the bin centres
# Factor to shift the bins relative to source and receiver points
jig = si / 2.
bin_centres = gpd.GeoSeries([Point(xmi + 0.5*r*ri + jig, ymi + 0.5*s*si + jig)
                             for r in range(2*rperline - 3)
                             for s in range(2*sperline - 2)
                            ])

# Buffers are diamond shaped so we have to scale and rotate them.
scale_factor = np.sin(np.pi/4.)/2.
bin_polys = bin_centres.buffer(scale_factor*ri, 1).rotate(-45)
bins = gpd.GeoDataFrame(geometry=bin_polys)

bins[:3]
# Out:
#                                             geometry
# 0  POLYGON ((1024831.457 1251702.027, 1024821.457...
# 1  POLYGON ((1024831.457 1251712.027, 1024821.457...
# 2  POLYGON ((1024831.457 1251722.027, 1024821.457...

# %%
bin_centres.plot(figsize=(12,12), markersize=5)
plt.grid()
plt.show()

# %%
# %matplotlib qt
#%matplotlib inline #To display image within the cell
bins.plot(figsize=(12,12), edgecolor="black") #Paul grafica la geometría encima, y los centros de los bins
# Out:
# <AxesSubplot:>

# %%
bins['seqbin']=range(291962) #Number of bins obtained from bin_centres.shape
bins
# Out:
#                                                  geometry  seqbin
# 0       POLYGON ((1024831.457 1251702.027, 1024821.457...       0
# 1       POLYGON ((1024831.457 1251712.027, 1024821.457...       1
# 2       POLYGON ((1024831.457 1251722.027, 1024821.457...       2
# 3       POLYGON ((1024831.457 1251732.027, 1024821.457...       3
# 4       POLYGON ((1024831.457 1251742.027, 1024821.457...       4
# ...                                                   ...     ...
# 291957  POLYGON ((1030591.457 1256712.027, 1030581.457...  291957
# 291958  POLYGON ((1030591.457 1256722.027, 1030581.457...  291958
# 291959  POLYGON ((1030591.457 1256732.027, 1030581.457...  291959
# 291960  POLYGON ((1030591.457 1256742.027, 1030581.457...  291960
# 291961  POLYGON ((1030591.457 1256752.027, 1030581.457...  291961
#
# [291962 rows x 2 columns]

# %%
def bin_the_midpoints(midpoints,bins):
    pointsInPolygon = gpd.sjoin(midpoints,bins, how="inner", op='intersects')
    pointsInPolygon['fold']=1
    pointsInPolygon.groupby('seqbin').sum()
    return gpd.GeoDataFrame(bins.join(pointsInPolygon.groupby('seqbin').sum()['fold']))

# %%
fold = bin_the_midpoints(midpoints,bins)#.fillna(-1) #Paul quita fillna(-1)
fold['fold']=np.ceil(fold['fold'].values/2)
fold.plot(column='fold',cmap='jet',edgecolor="None",legend=True, figsize=(10,12))
plt.show()
# Out:
# /Users/correa/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3437: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %% [markdown]
# ### Códigos de prueba:
# Crear columna idy con base en la coordenada ESTE y construir la matriz binaria de representación de la geometría, para calcular coherencia mutua

# %%
#Hacer matriz binaria de posiciones donde hay fuentes - no es posible usar la coordenada como indicador porque casi todos los shots tienen coordenada ESTE unica como se ve en la figura
print(source_survey.ESTE.unique().shape[0])
estes = source_survey.ESTE.unique()
plt.plot(estes, 'ob')
plt.grid()
plt.show()
# Out:
# 3286

# %% [markdown]
# Calculations required for the Fold:

# %%
len(midpoint_list)
# Out:
# 14703745

# %%
fold
# Out:
#                                                  geometry  seqbin  fold
# 0       POLYGON ((1024826.457 1251697.027, 1024816.457...       0  -1.0
# 1       POLYGON ((1024826.457 1251707.027, 1024816.457...       1  -1.0
# 2       POLYGON ((1024826.457 1251717.027, 1024816.457...       2  -1.0
# 3       POLYGON ((1024826.457 1251727.027, 1024816.457...       3  -1.0
# 4       POLYGON ((1024826.457 1251737.027, 1024816.457...       4  -1.0
# ...                                                   ...     ...   ...
# 291957  POLYGON ((1030586.457 1256707.027, 1030576.457...  291957  -1.0
# 291958  POLYGON ((1030586.457 1256717.027, 1030576.457...  291958  -1.0
# 291959  POLYGON ((1030586.457 1256727.027, 1030576.457...  291959  -1.0
# 291960  POLYGON ((1030586.457 1256737.027, 1030576.457...  291960  -1.0
# 291961  POLYGON ((1030586.457 1256747.027, 1030576.457...  291961  -1.0
#
# [291962 rows x 3 columns]

# %%
#Save Fold as a shapefile
fold.to_file('../data_geometry/Fold_Postplot/Fold_PostPlot_V1.shp')

# %%
fold.plot(column='fold',cmap='jet',legend=True)
plt.show()
