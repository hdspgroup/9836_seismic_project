# %%
pip install opencv-python tqdm hdf5storage
# Out:
# Requirement already satisfied: opencv-python in /data/Programacion/2022/9836_seismic_project/local_venv/lib/python3.10/site-packages (4.6.0.66)
# Requirement already satisfied: tqdm in /data/Programacion/2022/9836_seismic_project/local_venv/lib/python3.10/site-packages (4.64.0)
# Requirement already satisfied: hdf5storage in /data/Programacion/2022/9836_seismic_project/local_venv/lib/python3.10/site-packages (0.1.18)
# Requirement already satisfied: numpy>=1.21.2 in /data/Programacion/2022/9836_seismic_project/local_venv/lib/python3.10/site-packages (from opencv-python) (1.23.1)
# Requirement already satisfied: h5py>=2.1 in /data/Programacion/2022/9836_seismic_project/local_venv/lib/python3.10/site-packages (from hdf5storage) (3.7.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Ahora importamos los paquetes y funciones necesarias

# %%
import matplotlib.pyplot as plt
from Function import *
import matplotlib
from skimage.metrics import structural_similarity as ssim
import cv2
import numpy as np
from tqdm import tqdm
import hdf5storage

from main_fast_marching_approach import fastMarching_approach
# Out:
# /data/Programacion/2022/9836_seismic_project/local_venv/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %% [markdown]
# Ahora simplemente debemos colocar la dirección (data_path) del dato sismico que deseamos cargar para probar con el algoritmo. En la función "fastMarching_approach" debemos especificar también si el dato sismico esta guardado en el formato "numpy" o "matlab"

# %%
data_path = '../data/cube4.npy' # Stratton 3D Survey
fastMarching_approach(data_path, 'numpy')
# Out:
# 100%|██████████| 78/78 [00:01<00:00, 45.46it/s]
# 34.99044361969023
# Mean Result: 34.99044361969023

# %%
data_path = '../data/spii15s.npy' # SEAM Phase II Dataset
fastMarching_approach(data_path, 'numpy')
# Out:
# 100%|██████████| 98/98 [00:01<00:00, 89.16it/s]
# 32.75357794522429
# Mean Result: 32.75357794522429

# %%
data_path = '../data/syn3D_cross-spread2.npy' # Synthetic cross-spread seismic data modeled using finite differences
fastMarching_approach(data_path, 'numpy')
# Out:
# 100%|██████████| 99/99 [00:01<00:00, 53.09it/s]
# 36.78266971058231
# Mean Result: 36.78266971058231
